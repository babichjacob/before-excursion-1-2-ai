# %%
import os
import pathlib

# Clone the tensorflow models repository if it doesn't already exist
if "models" in pathlib.Path.cwd().parts:
  while "models" in pathlib.Path.cwd().parts:
    os.chdir('..')
elif not pathlib.Path('models').exists():
  # !git clone --depth 1 https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 3505, done.
# remote: Counting objects: 100% (3505/3505), done.
# remote: Compressing objects: 100% (2921/2921), done.
# remote: Total 3505 (delta 915), reused 1432 (delta 531), pack-reused 0
# Receiving objects: 100% (3505/3505), 46.98 MiB | 9.82 MiB/s, done.
# Resolving deltas: 100% (915/915), done.
# Updating files: 100% (3188/3188), done.

# %%
# Install the Object Detection API
# !cd models/research/ && protoc object_detection/protos/*.proto --python_out=.
# !cd models/research/ && cp object_detection/packages/tf2/setup.py .
# !cd models/research/ && python -m pip install .
# Out:
# Processing /home/jacob/Repositories/excursion-tensorflow/models/research
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: avro-python3 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from object-detection==0.1) (1.10.2)
# Requirement already satisfied: apache-beam in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from object-detection==0.1) (2.42.0)
# Requirement already satisfied: pillow in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from object-detection==0.1) (9.2.0)
# Requirement already satisfied: lxml in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from object-detection==0.1) (4.9.1)
# Requirement already satisfied: matplotlib in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from object-detection==0.1) (3.6.1)
# Requirement already satisfied: Cython in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from object-detection==0.1) (0.29.32)
# Requirement already satisfied: contextlib2 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from object-detection==0.1) (21.6.0)
# Requirement already satisfied: tf-slim in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from object-detection==0.1) (1.1.0)
# Requirement already satisfied: six in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from object-detection==0.1) (1.16.0)
# Requirement already satisfied: pycocotools in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from object-detection==0.1) (2.0.5)
# Requirement already satisfied: lvis in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from object-detection==0.1) (0.5.3)
# Requirement already satisfied: scipy in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from object-detection==0.1) (1.9.3)
# Requirement already satisfied: pandas in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from object-detection==0.1) (1.5.1)
# Requirement already satisfied: tf-models-official>=2.5.1 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from object-detection==0.1) (2.10.0)
# Requirement already satisfied: tensorflow_io in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from object-detection==0.1) (0.27.0)
# Requirement already satisfied: keras in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from object-detection==0.1) (2.11.0rc2)
# Collecting pyparsing==2.4.7
#   Using cached pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Requirement already satisfied: sacrebleu<=2.2.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from object-detection==0.1) (2.2.0)
# Requirement already satisfied: regex in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2022.9.13)
# Requirement already satisfied: colorama in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.4.5)
# Requirement already satisfied: numpy>=1.17 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (1.23.4)
# Requirement already satisfied: tabulate>=0.8.9 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.9.0)
# Requirement already satisfied: portalocker in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2.6.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.65.0)
# Requirement already satisfied: kaggle>=1.3.9 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.12)
# Requirement already satisfied: pyyaml<6.0,>=5.1 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.4.1)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (8.0.0)
# Requirement already satisfied: tensorflow-datasets in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.7.0)
# Requirement already satisfied: oauth2client in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: tensorflow-model-optimization>=0.4.1 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.7.3)
# Requirement already satisfied: tensorflow-text~=2.10.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.10.0)
# Requirement already satisfied: tensorflow-addons in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.18.0)
# Requirement already satisfied: immutabledict in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.2.1)
# Requirement already satisfied: psutil>=5.4.3 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.9.3)
# Requirement already satisfied: seqeval in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.2.2)
# Requirement already satisfied: sentencepiece in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.1.97)
# Requirement already satisfied: gin-config in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Collecting tensorflow~=2.10.0
#   Downloading tensorflow-2.10.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 578.1/578.1 MB 1.8 MB/s eta 0:00:0000:0100:01
# Collecting opencv-python-headless==4.5.2.52
#   Using cached opencv_python_headless-4.5.2.52-cp38-cp38-manylinux2014_x86_64.whl (38.2 MB)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.12.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from pandas->object-detection==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from pandas->object-detection==0.1) (2022.5)
# Requirement already satisfied: absl-py>=0.2.2 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tf-slim->object-detection==0.1) (1.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (2.28.1)
# Requirement already satisfied: pydot<2,>=1.2.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (1.4.2)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (0.18.0)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (1.22.1)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (2.7.0)
# Requirement already satisfied: orjson<4.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (3.8.0)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (0.3.1.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (1.6.1)
# Requirement already satisfied: httplib2<0.21.0,>=0.8 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (0.20.4)
# Requirement already satisfied: pyarrow<8.0.0,>=0.15.1 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (7.0.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (1.7)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (1.50.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (4.4.0)
# Collecting numpy>=1.17
#   Downloading numpy-1.22.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 11.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: protobuf<4,>=3.12.2 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (3.19.6)
# Requirement already satisfied: cloudpickle~=2.1.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (2.1.0)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (3.12.3)
# Requirement already satisfied: cycler>=0.10.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.1.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from lvis->object-detection==0.1) (1.4.4)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from lvis->object-detection==0.1) (4.5.5.64)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from matplotlib->object-detection==0.1) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from matplotlib->object-detection==0.1) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from matplotlib->object-detection==0.1) (21.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.27.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorflow_io->object-detection==0.1) (0.27.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.10.2)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.1.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.13.0)
# Requirement already satisfied: docopt in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1) (0.6.2)
# Requirement already satisfied: tqdm in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.64.1)
# Requirement already satisfied: python-slugify in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (6.1.2)
# Requirement already satisfied: urllib3 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.26.12)
# Requirement already satisfied: certifi in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (2.1.1)
# Requirement already satisfied: flatbuffers>=2.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (22.9.24)
# Requirement already satisfied: h5py>=2.9.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.7.0)
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 kB 15.5 MB/s eta 0:00:00
# Requirement already satisfied: google-pasta>=0.1.1 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (14.0.6)
# Requirement already satisfied: wrapt>=1.11.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.14.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (2.0.1)
# Requirement already satisfied: setuptools in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (65.5.0)
# Collecting keras
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 15.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: astunparse>=1.6.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (2.10.1)
# Requirement already satisfied: dm-tree~=0.1.1 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.7)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.3.0rc1)
# Requirement already satisfied: pyasn1>=0.1.7 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.5.0rc2)
# Requirement already satisfied: rsa>=3.1.4 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (4.9)
# Requirement already satisfied: scikit-learn>=0.21.3 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.1.2)
# Requirement already satisfied: typeguard>=2.7 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorflow-addons->tf-models-official>=2.5.1->object-detection==0.1) (2.13.3)
# Requirement already satisfied: tensorflow-metadata in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.10.0)
# Requirement already satisfied: toml in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.10.2)
# Requirement already satisfied: promise in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Requirement already satisfied: etils[epath] in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.8.0)
# Requirement already satisfied: importlib-resources in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (5.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.37.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.56.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (5.2.0)
# Requirement already satisfied: joblib>=1.0.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (2.2.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.6.1)
# Requirement already satisfied: zipp in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from etils[epath]->tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (3.10.0)
# Requirement already satisfied: text-unidecode>=1.3 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (2.1.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/jacob/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.2)
# Building wheels for collected packages: object-detection
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1696780 sha256=1282c62abb609a148c26194b25ceff4e1e9f519d08f6084490b3d8835663a28d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1y2n7y55/wheels/5c/55/17/0a5a7ac631a16012438675f895b5b23e67aa5429d5eae86822
# Successfully built object-detection
# Installing collected packages: keras, tensorflow-estimator, pyparsing, numpy, opencv-python-headless, tensorflow, object-detection
#   Attempting uninstall: keras
#     Found existing installation: keras 2.11.0rc2
#     Uninstalling keras-2.11.0rc2:
#       Successfully uninstalled keras-2.11.0rc2
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.11.0rc0
#     Uninstalling tensorflow-estimator-2.11.0rc0:
#       Successfully uninstalled tensorflow-estimator-2.11.0rc0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.4
#     Uninstalling numpy-1.23.4:
#       Successfully uninstalled numpy-1.23.4
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.5.5.64
#     Uninstalling opencv-python-headless-4.5.5.64:
#       Successfully uninstalled opencv-python-headless-4.5.5.64
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.11.0rc1
#     Uninstalling tensorflow-2.11.0rc1:
#       Successfully uninstalled tensorflow-2.11.0rc1
#   Attempting uninstall: object-detection
#     Found existing installation: object-detection 0.1
#     Uninstalling object-detection-0.1:
#       Successfully uninstalled object-detection-0.1
# Successfully installed keras-2.10.0 numpy-1.22.4 object-detection-0.1 opencv-python-headless-4.5.2.52 pyparsing-2.4.7 tensorflow-2.10.0 tensorflow-estimator-2.10.0
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: pip install --upgrade pip

# %%
import matplotlib
import matplotlib.pyplot as plt

import io
import scipy.misc
import numpy as np
from six import BytesIO
from PIL import Image, ImageDraw, ImageFont

import tensorflow as tf

from object_detection.utils import label_map_util
from object_detection.utils import config_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder

# %matplotlib inline

# %%
def load_image_into_numpy_array(path):
  """Load an image from file into a numpy array.

  Puts image into numpy array to feed into tensorflow graph.
  Note that by convention we put it into a numpy array with shape
  (height, width, channels), where channels=3 for RGB.

  Args:
    path: the file path to the image

  Returns:
    uint8 numpy array with shape (img_height, img_width, 3)
  """
  img_data = tf.io.gfile.GFile(path, 'rb').read()
  image = Image.open(BytesIO(img_data))
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)

def get_keypoint_tuples(eval_config):
  """Return a tuple list of keypoint edges from the eval config.
  
  Args:
    eval_config: an eval config containing the keypoint edges
  
  Returns:
    a list of edge tuples, each in the format (start, end)
  """
  tuple_list = []
  kp_list = eval_config.keypoint_edge
  for edge in kp_list:
    tuple_list.append((edge.start, edge.end))
  return tuple_list

# %%
# @title Choose the model to use, then evaluate the cell.
MODELS = {'centernet_with_keypoints': 'centernet_hg104_512x512_kpts_coco17_tpu-32', 'centernet_without_keypoints': 'centernet_hg104_512x512_coco17_tpu-8'}

model_display_name = 'centernet_with_keypoints' # @param ['centernet_with_keypoints', 'centernet_without_keypoints']
model_name = MODELS[model_display_name]

# %%
# Download the checkpoint and put it into models/research/object_detection/test_data/

if model_display_name == 'centernet_with_keypoints':
  # !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/centernet_hg104_512x512_kpts_coco17_tpu-32.tar.gz
  # !tar -xf centernet_hg104_512x512_kpts_coco17_tpu-32.tar.gz
  # !mv centernet_hg104_512x512_kpts_coco17_tpu-32/checkpoint models/research/object_detection/test_data/
else:
  # !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/centernet_hg104_512x512_coco17_tpu-8.tar.gz
  # !tar -xf centernet_hg104_512x512_coco17_tpu-8.tar.gz
  # !mv centernet_hg104_512x512_coco17_tpu-8/checkpoint models/research/object_detection/test_data/
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages/IPython/utils/_process_posix.py:148, in ProcessHandler.system(self, cmd)
#     147 else:
# --> 148     child = pexpect.spawn(self.sh, args=['-c', cmd])  # Vanilla Pexpect
#     149 flush = sys.stdout.flush
#
# File ~/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages/pexpect/pty_spawn.py:205, in spawn.__init__(self, command, args, timeout, maxread, searchwindowsize, logfile, cwd, env, ignore_sighup, echo, preexec_fn, encoding, codec_errors, dimensions, use_poll)
#     204 else:
# --> 205     self._spawn(command, args, preexec_fn, dimensions)
#     206 self.use_poll = use_poll
#
# File ~/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages/pexpect/pty_spawn.py:303, in spawn._spawn(self, command, args, preexec_fn, dimensions)
#     300     self.args = [a if isinstance(a, bytes) else a.encode(self.encoding)
#     301                  for a in self.args]
# --> 303 self.ptyproc = self._spawnpty(self.args, env=self.env,
#     304                              cwd=self.cwd, **kwargs)
#     306 self.pid = self.ptyproc.pid
#
# File ~/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages/pexpect/pty_spawn.py:315, in spawn._spawnpty(self, args, **kwargs)
#     314 '''Spawn a pty and return an instance of PtyProcess.'''
# --> 315 return ptyprocess.PtyProcess.spawn(args, **kwargs)
#
# File ~/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages/ptyprocess/ptyprocess.py:315, in PtyProcess.spawn(cls, argv, cwd, env, echo, preexec_fn, dimensions, pass_fds)
#     314 os.close(exec_err_pipe_write)
# --> 315 exec_err_data = os.read(exec_err_pipe_read, 4096)
#     316 os.close(exec_err_pipe_read)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# Cell In [6], line 4
#       1 # Download the checkpoint and put it into models/research/object_detection/test_data/
#       3 if model_display_name == 'centernet_with_keypoints':
# ----> 4   get_ipython().system('wget http://download.tensorflow.org/models/object_detection/tf2/20200711/centernet_hg104_512x512_kpts_coco17_tpu-32.tar.gz')
#       5   get_ipython().system('tar -xf centernet_hg104_512x512_kpts_coco17_tpu-32.tar.gz')
#       6   get_ipython().system('mv centernet_hg104_512x512_kpts_coco17_tpu-32/checkpoint models/research/object_detection/test_data/')
#
# File ~/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages/ipykernel/zmqshell.py:633, in ZMQInteractiveShell.system_piped(self, cmd)
#     631         self.user_ns["_exit_code"] = system(cmd)
#     632 else:
# --> 633     self.user_ns["_exit_code"] = system(self.var_expand(cmd, depth=1))
#
# File ~/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages/IPython/utils/_process_posix.py:164, in ProcessHandler.system(self, cmd)
#     159         out_size = len(child.before)
#     160 except KeyboardInterrupt:
#     161     # We need to send ^C to the process.  The ascii code for '^C' is 3
#     162     # (the character is known as ETX for 'End of Text', see
#     163     # curses.ascii.ETX).
# --> 164     child.sendline(chr(3))
#     165     # Read and print any more output the program might produce on its
#     166     # way out.
#     167     try:
#
# UnboundLocalError: local variable 'child' referenced before assignment

# %%
pipeline_config = os.path.join('models/research/object_detection/configs/tf2/',
                                model_name + '.config')
model_dir = 'models/research/object_detection/test_data/checkpoint/'

# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(pipeline_config)
model_config = configs['model']
detection_model = model_builder.build(
      model_config=model_config, is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(
      model=detection_model)
ckpt.restore(os.path.join(model_dir, 'ckpt-0')).expect_partial()

def get_model_detection_function(model):
  """Get a tf.function for detection."""

  @tf.function
  def detect_fn(image):
    """Detect objects in image."""

    image, shapes = model.preprocess(image)
    prediction_dict = model.predict(image, shapes)
    detections = model.postprocess(prediction_dict, shapes)

    return detections, prediction_dict, tf.reshape(shapes, [-1])

  return detect_fn

detect_fn = get_model_detection_function(detection_model)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In [7], line 6
#       3 model_dir = 'models/research/object_detection/test_data/checkpoint/'
#       5 # Load pipeline config and build a detection model
# ----> 6 configs = config_util.get_configs_from_pipeline_file(pipeline_config)
#       7 model_config = configs['model']
#       8 detection_model = model_builder.build(
#       9       model_config=model_config, is_training=False)
#
# File ~/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages/object_detection/utils/config_util.py:138, in get_configs_from_pipeline_file(pipeline_config_path, config_override)
#     136 pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
#     137 with tf.gfile.GFile(pipeline_config_path, "r") as f:
# --> 138   proto_str = f.read()
#     139   text_format.Merge(proto_str, pipeline_config)
#     140 if config_override:
#
# File ~/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages/tensorflow/python/lib/io/file_io.py:114, in FileIO.read(self, n)
#     102 def read(self, n=-1):
#     103   """Returns the contents of a file as a string.
#     104
#     105   Starts reading from current position in file.
#    (...)
#     112     string if in string (regular) mode.
#     113   """
# --> 114   self._preread_check()
#     115   if n == -1:
#     116     length = self.size() - self.tell()
#
# File ~/.local/share/virtualenvs/excursion-tensorflow-AjiJEs0D/lib/python3.8/site-packages/tensorflow/python/lib/io/file_io.py:76, in FileIO._preread_check(self)
#      73 if not self._read_check_passed:
#      74   raise errors.PermissionDeniedError(None, None,
#      75                                      "File isn't open for reading")
# ---> 76 self._read_buf = _pywrap_file_io.BufferedInputStream(
#      77     compat.path_to_str(self.__name), 1024 * 512)
#
# NotFoundError: models/research/object_detection/configs/tf2/centernet_hg104_512x512_kpts_coco17_tpu-32.config; No such file or directory

# %%
label_map_path = configs['eval_input_config'].label_map_path
label_map = label_map_util.load_labelmap(label_map_path)
categories = label_map_util.convert_label_map_to_categories(
    label_map,
    max_num_classes=label_map_util.get_max_label_map_index(label_map),
    use_display_name=True)
category_index = label_map_util.create_category_index(categories)
label_map_dict = label_map_util.get_label_map_dict(label_map, use_display_name=True)

# %%
image_dir = 'models/research/object_detection/test_images/'
image_path = os.path.join(image_dir, 'image2.jpg')
image_np = load_image_into_numpy_array(image_path)

# Things to try:
# Flip horizontally
# image_np = np.fliplr(image_np).copy()

# Convert image to grayscale
# image_np = np.tile(
#     np.mean(image_np, 2, keepdims=True), (1, 1, 3)).astype(np.uint8)

input_tensor = tf.convert_to_tensor(
    np.expand_dims(image_np, 0), dtype=tf.float32)
detections, predictions_dict, shapes = detect_fn(input_tensor)

label_id_offset = 1
image_np_with_detections = image_np.copy()

# Use keypoints if available in detections
keypoints, keypoint_scores = None, None
if 'detection_keypoints' in detections:
  keypoints = detections['detection_keypoints'][0].numpy()
  keypoint_scores = detections['detection_keypoint_scores'][0].numpy()

viz_utils.visualize_boxes_and_labels_on_image_array(
      image_np_with_detections,
      detections['detection_boxes'][0].numpy(),
      (detections['detection_classes'][0].numpy() + label_id_offset).astype(int),
      detections['detection_scores'][0].numpy(),
      category_index,
      use_normalized_coordinates=True,
      max_boxes_to_draw=200,
      min_score_thresh=.30,
      agnostic_mode=False,
      keypoints=keypoints,
      keypoint_scores=keypoint_scores,
      keypoint_edges=get_keypoint_tuples(configs['eval_config']))

plt.figure(figsize=(12,16))
plt.imshow(image_np_with_detections)
plt.show()
